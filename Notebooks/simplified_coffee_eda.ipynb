# %% [markdown]
# There are nine variables in the dataset as follows:
#
# name: Name of the blend
# roaster: Name of the roaster
# roast: Type of roast (Light, Medium-Light, Medium, Medium-Dark, Dark)
# loc_country: Location of the roaster
# origin: Origin of the beans
# 100g_USD: Price per 100g (roughly 1/4 lb) of beans in US dollars
# rating: Rating of the coffee
# review_date: Date of the coffee review
# review: Text of review

# %% [markdown]
# Import libraries and dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sqlite3

df = pd.read_csv('../Data/simplified_coffee_cleaned.csv')

# %% [markdown]
# Get an overview of the data in the next few cells.

# %%
df.head()
# Out:
#                                name                     roaster         roast  \
# 0          Ethiopia Shakiso Mormora                Revel Coffee  Medium-Light
# 1                Ethiopia Suke Quto                 Roast House  Medium-Light
# 2        Ethiopia Gedeb Halo Beriti   Big Creek Coffee Roasters        Medium
# 3           Ethiopia Kayon Mountain  Red Rooster Coffee Roaster         Light
# 4  Ethiopia Gelgelu Natural Organic   Willoughby's Coffee & Tea  Medium-Light
#
#      loc_country    origin  100g_USD  rating    review_date  \
# 0  United States  Ethiopia      4.70      92  November 2017
# 1  United States  Ethiopia      4.19      92  November 2017
# 2  United States  Ethiopia      4.85      94  November 2017
# 3  United States  Ethiopia      5.14      93  November 2017
# 4  United States  Ethiopia      3.97      93  November 2017
#
#                                               review
# 0  Crisply sweet, cocoa-toned. Lemon blossom, roa...
# 1  Delicate, sweetly spice-toned. Pink peppercorn...
# 2  Deeply sweet, subtly pungent. Honey, pear, tan...
# 3  Delicate, richly and sweetly tart. Dried hibis...
# 4  High-toned, floral. Dried apricot, magnolia, a...

# %% [markdown]
# Explore the columns

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1234 non-null   str
#  1   roaster      1234 non-null   str
#  2   roast        1234 non-null   str
#  3   loc_country  1234 non-null   str
#  4   origin       1234 non-null   str
#  5   100g_USD     1234 non-null   float64
#  6   rating       1234 non-null   int64
#  7   review_date  1234 non-null   str
#  8   review       1234 non-null   str
# dtypes: float64(1), int64(1), str(7)
# memory usage: 86.9 KB

# %%
df.shape
# Out:
# (1234, 9)

# %% [markdown]
# There might be 12 null values in the roast column.
#
# Now I need to check data types, which I can see above, but I will write code for it anyway.

# %%
print(df.dtypes)
# Out:
# name               str
# roaster            str
# roast              str
# loc_country        str
# origin             str
# 100g_USD       float64
# rating           int64
# review_date        str
# review             str
# dtype: object

# %% [markdown]
# There is a good mix of strings and numbers (floats and integers).  I might need to separate the individual words out of the review column for analysis.
#
# Next, I will check for null values.

# %%
df.isnull()
# Out:
#        name  roaster  roast  loc_country  origin  100g_USD  rating  \
# 0     False    False  False        False   False     False   False
# 1     False    False  False        False   False     False   False
# 2     False    False  False        False   False     False   False
# 3     False    False  False        False   False     False   False
# 4     False    False  False        False   False     False   False
# ...     ...      ...    ...          ...     ...       ...     ...
# 1229  False    False  False        False   False     False   False
# 1230  False    False  False        False   False     False   False
# 1231  False    False  False        False   False     False   False
# 1232  False    False  False        False   False     False   False
# 1233  False    False  False        False   False     False   False
#
#       review_date  review
# 0           False   False
# 1           False   False
# 2           False   False
# 3           False   False
# 4           False   False
# ...           ...     ...
# 1229        False   False
# 1230        False   False
# 1231        False   False
# 1232        False   False
# 1233        False   False
#
# [1234 rows x 9 columns]

# %% [markdown]
# Since the df only shows me the first and last 5 records, I don't know which rows contain the null values.

# %%
df.isna()
# Out:
#        name  roaster  roast  loc_country  origin  100g_USD  rating  \
# 0     False    False  False        False   False     False   False
# 1     False    False  False        False   False     False   False
# 2     False    False  False        False   False     False   False
# 3     False    False  False        False   False     False   False
# 4     False    False  False        False   False     False   False
# ...     ...      ...    ...          ...     ...       ...     ...
# 1229  False    False  False        False   False     False   False
# 1230  False    False  False        False   False     False   False
# 1231  False    False  False        False   False     False   False
# 1232  False    False  False        False   False     False   False
# 1233  False    False  False        False   False     False   False
#
#       review_date  review
# 0           False   False
# 1           False   False
# 2           False   False
# 3           False   False
# 4           False   False
# ...           ...     ...
# 1229        False   False
# 1230        False   False
# 1231        False   False
# 1232        False   False
# 1233        False   False
#
# [1234 rows x 9 columns]

# %% [markdown]
# df.isna() and df.isnull() do the same thing and don't tell me what I need to know, which is which rows contain the null values.
#
# Next, I will try this:

# %%
null_rows = df[df['roast'].isnull()]
print(null_rows)
# Out:
# Empty DataFrame
# Columns: [name, roaster, roast, loc_country, origin, 100g_USD, rating, review_date, review]
# Index: []

# %% [markdown]
# There are twelve null rows.  I am going to drop them since it's just a few rows and I have enough data otherwise.  I could fill in the missing data with the most common value (type of roast) but it might be inaccurate.  To drop the rows, I need to write dropna() and assign it to a variable.
#
# According to W3 Schools, "The dropna() method returns a new DataFrame object unless the inplace parameter is set to True, in that case the dropna() method does the removing in the original DataFrame instead." I originally did inplace = True before I discovered it was best to assign it to a variable.  I might have modified the original DataFrame.

# %%
df = df.dropna()

# %% [markdown]
# Determine if the dropna() was successful:

# %%
df.shape
# Out:
# (1234, 9)

# %% [markdown]
# As you can see, the dropna() was successful, as there are now only 1234 rows.

# %% [markdown]
# Now, I will check again for any null values in the entire DataFrame.

# %%
df.isnull().sum()
# Out:
# name           0
# roaster        0
# roast          0
# loc_country    0
# origin         0
# 100g_USD       0
# rating         0
# review_date    0
# review         0
# dtype: int64

# %% [markdown]
# There are no null values in the DataFrame.

# %% [markdown]
# Now I need to check for unique values in the DataFrame. It will return a Series containing counts of unique values.

# %%
df['name'].value_counts()
# Out:
# name
# Ethiopia Kayon Mountain                  6
# Kona Mocca®                              5
# 100% Kona Bourbon Pointu Laurina         4
# Bella Carmona Guatemala                  4
# Guatemala Bella Carmona                  4
#                                         ..
# Ethiopia Guji Hambela Wate Natural G1    1
# Finca Patzibir                           1
# Finca El Potrero                         1
# Chacayá Santiago Atitlán                 1
# Espresso No. 3                           1
# Name: count, Length: 1134, dtype: int64

# %%
df['roaster'].value_counts()
# Out:
# roaster
# Kakalove Cafe                       91
# JBC Coffee Roasters                 91
# Paradise Roasters                   83
# Dragonfly Coffee Roasters           30
# Bird Rock Coffee Roasters           29
#                                     ..
# JYL Cafe                             1
# Balmy Day Coffee Office              1
# Dr. Young Cafe                       1
# San Francisco Bay Coffee Company     1
# Durango Coffee Companuy              1
# Name: count, Length: 298, dtype: int64

# %%
df['roast'].value_counts()
# Out:
# roast
# Medium-Light    904
# Light           198
# Medium          114
# Medium-Dark      15
# Dark              3
# Name: count, dtype: int64

# %%
df['loc_country'].value_counts()
# Out:
# loc_country
# United States    771
# Taiwan           334
# Hawai'i           77
# Guatemala         24
# Hong Kong          9
# Japan              8
# Canada             5
# England            2
# Australia          1
# China              1
# Kenya              1
# New Taiwan         1
# Name: count, dtype: int64

# %%
df['origin'].value_counts()
# Out:
# origin
# Ethiopia                            443
# Colombia                            151
# Kenya                               143
# Hawai'I                             113
# Guatemala                            96
# Panama                               65
# Costa Rica                           46
# Indonesia                            28
# Democratic Republic Of The Congo     14
# El Salvador                          14
# Peru                                 13
# Brazil                               13
# Rwanda                               12
# Burundi                              12
# Yemen                                12
# Nicaragua                            11
# Mexico                               11
# Taiwan                                9
# Ecuador                               8
# Honduras                              6
# Nepal                                 2
# Bolivia                               2
# Dominican Republic                    2
# Thailand                              2
# Uganda                                2
# Tanzania                              2
# Philippines                           2
# Name: count, dtype: int64

# %%
df['origin'].value_counts().head(10)
#Tells us the top coffee-growing countries by quantity
# Out:
# origin
# Ethiopia                            443
# Colombia                            151
# Kenya                               143
# Hawai'I                             113
# Guatemala                            96
# Panama                               65
# Costa Rica                           46
# Indonesia                            28
# Democratic Republic Of The Congo     14
# El Salvador                          14
# Name: count, dtype: int64

# %%
df['100g_USD'].value_counts()
# Out:
# 100g_USD
# 5.29     68
# 5.58     51
# 5.88     50
# 6.47     30
# 6.17     29
#          ..
# 9.04      1
# 1.36      1
# 14.16     1
# 6.08      1
# 8.11      1
# Name: count, Length: 338, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# 93    356
# 94    349
# 92    184
# 95    177
# 91     60
# 90     43
# 96     43
# 97     10
# 89      3
# 88      3
# 87      3
# 86      2
# 84      1
# Name: count, dtype: int64

# %%
df['review_date'].value_counts()
# Out:
# review_date
# October 2020     51
# November 2021    38
# November 2020    36
# June 2022        35
# October 2022     35
#                  ..
# March 2020        8
# June 2018         7
# January 2020      7
# January 2019      6
# July 2018         3
# Name: count, Length: 61, dtype: int64

# %%
df['review'].value_counts()
# Out:
# review
# %%
df['origin'].value_counts().head(10)
# Out:
# origin
# Ethiopia                            443
# Colombia                            151
# Kenya                               143
# Hawai'I                             113
# Guatemala                            96
# Panama                               65
# Costa Rica                           46
# Indonesia                            28
# Democratic Republic Of The Congo     14
# El Salvador                          14
# Name: count, dtype: int64

# %% [markdown]
# Find the top ten roasters by number of coffees produced.

# %%
df['roaster'].value_counts().head(10)
# Out:
# roaster
# Kakalove Cafe                 91
# JBC Coffee Roasters           91
# Paradise Roasters             83
# Dragonfly Coffee Roasters     30
# Bird Rock Coffee Roasters     29
# Temple Coffee Roasters        27
# Hula Daddy Kona Coffee        24
# GK Coffee                     23
# Red Rooster Coffee Roaster    18
# RamsHead Coffee Roasters      18
# Name: count, dtype: int64

# %% [markdown]
# Top 10 coffee-producing countries

# %%
df['loc_country'].value_counts().head(10)
# Out:
# loc_country
# United States    771
# Taiwan           334
# Hawai'i           77
# Guatemala         24
# Hong Kong          9
# Japan              8
# Canada             5
# England            2
# Australia          1
# China              1
# Name: count, dtype: int64

# %% [markdown]
# Check for duplicates:

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1229    False
# 1230    False
# 1231    False
# 1232    False
# 1233    False
# Length: 1234, dtype: bool

# %% [markdown]
# Show duplicate rows, since above output is truncated. You can't see any duplicated rows.
# In this case, there are no duplicate rows. It returned an empty DataFrame.

# %%
duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [name, roaster, roast, loc_country, origin, 100g_USD, rating, review_date, review]
# Index: []

# %% [markdown]
# .loc[] lets you access data by label (like row names or column names).
# .iloc[] lets you access data by position (like row or column number).
# Filtering and indexing using .loc and .iloc:

# %%
df.to_csv('../Data/simplified_coffee_cleaned.csv', index = False)

# %% [markdown]
# Create database from coffee_ERD:

# %%
conn = sqlite3.connect('../Data/simplified_coffee.db')

coffee_df = df[['name', 'roaster', 'roast', 'loc_country', 'origin', '100g_USD']].drop_duplicates()

coffee_rating_df = df[['rating', 'name', 'review_date', 'review']].drop_duplicates()

coffee_df.to_sql('coffee', conn, index = False, if_exists = 'replace')
coffee_rating_df.to_sql('coffee_rating', conn, index = False, if_exists = 'replace')

conn.commit
# Out:
# <function Connection.commit()>

# %%
coffee_df.to_csv('../Data/coffee')
coffee_rating_df.to_csv('../Data/coffee_rating')

# %% [markdown]
# I will query the coffee database.

# %% [markdown]
# Which countries produce the beans for the highest-rated coffee?

# %%
query1 = """
SELECT
    c.origin,
    cr.rating
FROM coffee c
JOIN coffee_rating cr ON c.name = cr.name
WHERE rating = 97 
GROUP BY c.origin
"""

# %%
#execute the query
result1 = pd.read_sql_query(query1, conn)
result1
#This tells us the top four countries and one US state according to quality.
# Out:
#      origin  rating
# 0  Colombia      97
# 1  Ethiopia      97
# 2   Hawai'I      97
# 3     Kenya      97
# 4    Panama      97

# %%
conn.close()
